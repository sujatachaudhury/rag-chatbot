# %% [markdown]
# ### Data Ingesion

# %%
### Document Structure

from langchain_core.documents import Document

# %%
doc=Document(
    page_content="this is the main text content I am using to create RAG",
    metadata={
        "source": "example.txt",
        "pages":1,
        "author":"Mim",
        "date_created":"2026-01-01"
    }
)
doc
# Out:
# Document(metadata={'source': 'example.txt', 'pages': 1, 'author': 'Mim', 'date_created': '2026-01-01'}, page_content='this is the main text content I am using to create RAG')

# %%
### crete a simple txt file
import os
os.makedirs("../data/text_files", exist_ok=True)

# %%
sample_texts={
    "../data/text_files/python_intro.txt":"""Python Programming Introduction

Python is a high-level, interpreted programming language known for its simplicity and readability.
Created by Guido van Rossum and first released in 1991, Python has become one of the most popular
programming languages in the world.

Key Features:
- Easy to learn and use
- Extensive standard library
- Cross-platform compatibility
- Strong community support

Python is widely used in web development, data science, artificial intelligence, and automation.""",
    
    "../data/text_files/machine_learning.txt": """Machine Learning Basics

Machine learning is a subset of artificial intelligence that enables systems to learn and improve
from experience without being explicitly programmed. It focuses on developing computer programs
that can access data and use it to learn for themselves.

Types of Machine Learning:
1. Supervised Learning: Learning with labeled data
2. Unsupervised Learning: Finding patterns in unlabeled data
3. Reinforcement Learning: Learning through rewards and penalties

Applications include image recognition, speech processing, and recommendation systems
    
    
    """
}

for filepath, content in sample_texts.items():
    with open(filepath, 'w', encoding="utf-8") as f:
        f.write(content)

print("Sample text files created")
# Out:
# Sample text files created

# %%
### TextLoader

from langchain_community.document_loaders import TextLoader

loader=TextLoader("../data/text_files/python_intro.txt", encoding="utf-8")
document = loader.load()
print(document)
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.')]

# %%
### Directory Loader

from langchain_community.document_loaders import DirectoryLoader

## load all files from the directory
dir_loader = DirectoryLoader(
    "../data/text_files",
    glob="**/*.txt",
    loader_cls= TextLoader,
    loader_kwargs={'encoding': 'utf-8'},
    show_progress=False
)

documents=dir_loader.load()
documents
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.'),
#  Document(metadata={'source': '../data/text_files/machine_learning.txt'}, page_content='Machine Learning Basics\n\nMachine learning is a subset of artificial intelligence that enables systems to learn and improve\nfrom experience without being explicitly programmed. It focuses on developing computer programs\nthat can access data and use it to learn for themselves.\n\nTypes of Machine Learning:\n1. Supervised Learning: Learning with labeled data\n2. Unsupervised Learning: Finding patterns in unlabeled data\n3. Reinforcement Learning: Learning through rewards and penalties\n\nApplications include image recognition, speech processing, and recommendation systems\n\n\n    ')]

# %%
### Directory Loader

from langchain_community.document_loaders import PyMuPDFLoader, PyPDFLoader

## load all files from the directory
dir_loader = DirectoryLoader(
    "../data/pdfs",
    glob="**/*.pdf",
    loader_cls= PyMuPDFLoader,
    show_progress=False
)

pdf_documents=dir_loader.load()
pdf_documents
# Out:
# [Document(metadata={'producer': 'pdfTeX, Version 3.141592653-2.6-1.40.26 (TeX Live 2024) kpathsea version 6.4.0', 'creator': 'LaTeX with acmart 2025/05/30 v2.14 Typesetting articles for the Association for Computing Machinery and hyperref 2024-01-20 v7.01h Hypertext links for LaTeX', 'creationdate': '2025-07-30T06:58:56+00:00', 'source': '../data/pdfs/Floe Sparse 4DGS.pdf', 'file_path': '../data/pdfs/Floe Sparse 4DGS.pdf', 'total_pages': 10, 'format': 'PDF 1.5', 'title': 'Sparse4DGS: Flow-Geometry Assisted 4D Gaussian Splatting for Dynamic Sparse View Synthesis', 'author': 'Dongdong Hu', 'subject': '-  Computing methodologies  ->  Rendering.Reconstruction.Virtual reality.', 'keywords': '3D Gaussian Splatting; Sparse-View Synthesis; Dynamic Scene Reconstruction', 'moddate': '2025-09-29T14:47:17-04:00', 'trapped': '', 'modDate': "D:20250929144717-04'00'", 'creationDate': 'D:20250730065856Z', 'page': 0}, page_content='Sparse4DGS: Flow-Geometry Assisted 4D Gaussian Splatting for\nDynamic Sparse View Synthesis\nDongdong Hu\nHangzhou Dianzi University\nHangzhou, China\n232080175@hdu.edu.cn\nYang Zhou∗\nHangzhou Dianzi University\nHangzhou, China\nzhouyang@hdu.edu.cn\nXiaofeng Huang\nHangzhou Dianzi University\nHangzhou, China\nxfhuang@hdu.edu.cn\nHaibing Yin\nHangzhou Dianzi University\nHangzhou, China\nyhb@hdu.edu.cn\nZhu Li\nUniversity of Missouri-Kansas City\nKansas City, MO, USA\nzhu.li@ieee.org\nAbstract\nPrevious dynamic view synthesis works often struggle with limited\navailable views, resulting in noticeable artifacts and blurriness in\nthe outputs. In this paper, we present Sparse4DGS, a novel 4D Gauss-\nian splatting framework that enables high-fidelity view synthesis\nfrom sparse inputs through three key innovations: 1) a global-local\nfeature extraction encoder that integrates global Hexplane fields\nwith local hash grids, effectively capturing both rough backgrounds\nand fine details; 2) a flow-guided feature aggregation module that\nstabilizes dynamic 3D Gaussians between adjacent frames, ensuring\ntemporal continuity; and 3) a 4D geometry constraint scheme that\nutilizes monocular depth and pseudo-viewpoint depth supervision\nto enhance the structural consistency of dynamic scene details.\nOur approach achieves higher rendering quality while maintain-\ning model compactness. Experimental results on various bench-\nmarks demonstrate that our method performs favorably against\nstate-of-the-art methods in terms of both rendering quality and\ntraining time. The source code and trained models are available at\nhttps://github.com/hu-dong-dong/Sparse4DGS.\nCCS Concepts\n• Computing methodologies →Rendering; Reconstruction;\nVirtual reality.\nKeywords\n3D Gaussian Splatting; Sparse-View Synthesis; Dynamic Scene Re-\nconstruction\nACM Reference Format:\nDongdong Hu, Yang Zhou, Xiaofeng Huang, Haibing Yin, and Zhu Li. 2025.\nSparse4DGS: Flow-Geometry Assisted 4D Gaussian Splatting for Dynamic\n∗Corresponding Author.\nPermission to make digital or hard copies of all or part of this work for personal or\nclassroom use is granted without fee provided that copies are not made or distributed\nfor profit or commercial advantage and that copies bear this notice and the full citation\non the first page. Copyrights for components of this work owned by others than the\nauthor(s) must be honored. Abstracting with credit is permitted. To copy otherwise, or\nrepublish, to post on servers or to redistribute to lists, requires prior specific permission\nand/or a fee. Request permissions from permissions@acm.org.\nMM ’25, Dublin, Ireland.\n© 2025 Copyright held by the owner/author(s). Publication rights licensed to ACM.\nACM ISBN 979-8-4007-2035-2/2025/10\nhttps://doi.org/10.1145/3746027.3755819\nFigure 1: Quantitative evaluation on Neural 3D Video (6-view\nsparse input), where point radii indicate memory usage. Our\napproach outperforms state-of-the-art methods in render-\ning quality, training efficiency, and model compactness for\nsparse-vi ...
#  Document(metadata={'producer': 'pdfTeX, Version 3.141592653-2.6-1.40.26 (TeX Live 2024) kpathsea version 6.4.0', 'creator': 'LaTeX with acmart 2025/05/30 v2.14 Typesetting articles for the Association for Computing Machinery and hyperref 2024-01-20 v7.01h Hypertext links for LaTeX', 'creationdate': '2025-07-30T06:58:56+00:00', 'source': '../data/pdfs/Floe Sparse 4DGS.pdf', 'file_path': '../data/pdfs/Floe Sparse 4DGS.pdf', 'total_pages': 10, 'format': 'PDF 1.5', 'title': 'Sparse4DGS: Flow-Geometry Assisted 4D Gaussian Splatting for Dynamic Sparse View Synthesis', 'author': 'Dongdong Hu', 'subject': '-  Computing methodologies  ->  Rendering.Reconstruction.Virtual reality.', 'keywords': '3D Gaussian Splatting; Sparse-View Synthesis; Dynamic Scene Reconstruction', 'moddate': '2025-09-29T14:47:17-04:00', 'trapped': '', 'modDate': "D:20250929144717-04'00'", 'creationDate': 'D:20250730065856Z', 'page': 1}, page_content='MM ’25, October 27–31, 2025, Dublin, Ireland.\nDongdong Hu et al.\nRecently, 3D Gaussian Splatting (3D-GS) [11] builds on the con-\ncepts of NeRFs but replaces the implicit neural network with an ex-\nplicit representation based on 3D Gaussians. This approach achieves\nhigh-quality real-time rendering through tile-based rasterization,\nproviding a promising alternative to NeRF. However, 3DGS pri-\nmarily focuses on static scene reconstruction, and extending it\nto dynamic scenarios remains a challenging research area. Sim-\nilar to dynamic NeRF, some studies [21, 24, 25, 38, 41, 44, 48]\ncombine an implicit MLP-based deformation field with explicit\npoint cloud representation to learn the deformation of Gaussian\n(including position, scale, and rotation matrices) . Other reseaches\n[9, 10, 13, 15, 18, 20, 45] directly incorporates temporal dimensions\ninto the position of each Gaussian, allowing for 4D modeling of\ntime-varying scenes. However, both families of methods exhibit\nsignificant performance degradation under sparse view conditions.\nThis is mainly due to the initial point clouds being overly scattered,\nwhich is hard to accurately represent high-variance regions. Specif-\nically, synthesizing novel dynamic views from sparse viewpoints\nencounters three primary issues. First, the scarcity of information\nin sparse training data exacerbates the difficulty of capturing high-\nfrequency details of the scene. Second, sparse sampling leads to more\nsignificant gaps in temporal continuity. Lastly, limited viewpoints\ncreate geometric uncertainty.\nIn this paper, we address the abovementioned challenges by\nleveraging a global-local representation for 4D GS and proposing\na flow-geometry-assisted 4D Gaussian framework for modeling\ndynamic scenes from sparse views. First, to improve the represen-\ntation of high-frequency dynamic scenes in these sparse settings,\nwe employ a six-plane encoder to extract low-frequency global\nfeatures while simultaneously using a parallel hash grid volume\nencoder to capture high-frequency local features. Second, to ensure\nfeature coherence between frames in sparse scenes, inspired by the\nflow MLP[17, 50], we predict the Gaussian flow direction, extract\nfeatures from the warped Gaussian points, and use feature aggre-\ngation for motion compensation. Lastly, to address the geometric\nstructure inconsistency caused by sparse initialization, we use a\ncombination of aligned 2D depth priors with Pearson correlation\nloss and depth supervision under 4D pseudo-camera poses.\nOur main contributions can be summarized as follows:\n• The first unified framework combining Hexplane’s global\ndynamics with hash grids for sparse-view local detail preser-\nvation.\n• The proposed system synergistically incorporates two key\nauxiliary modules: a flow-guided feature aggregation com-\nponent that maintains scene continuity, and a 4D geometry-\nconstraint optimization module that enforces spatial coher-\nence.\n• Extensive experiments demonstrate that our method out-\nperforms previous approaches ...
#  Document(metadata={'producer': 'pdfTeX, Version 3.141592653-2.6-1.40.26 (TeX Live 2024) kpathsea version 6.4.0', 'creator': 'LaTeX with acmart 2025/05/30 v2.14 Typesetting articles for the Association for Computing Machinery and hyperref 2024-01-20 v7.01h Hypertext links for LaTeX', 'creationdate': '2025-07-30T06:58:56+00:00', 'source': '../data/pdfs/Floe Sparse 4DGS.pdf', 'file_path': '../data/pdfs/Floe Sparse 4DGS.pdf', 'total_pages': 10, 'format': 'PDF 1.5', 'title': 'Sparse4DGS: Flow-Geometry Assisted 4D Gaussian Splatting for Dynamic Sparse View Synthesis', 'author': 'Dongdong Hu', 'subject': '-  Computing methodologies  ->  Rendering.Reconstruction.Virtual reality.', 'keywords': '3D Gaussian Splatting; Sparse-View Synthesis; Dynamic Scene Reconstruction', 'moddate': '2025-09-29T14:47:17-04:00', 'trapped': '', 'modDate': "D:20250929144717-04'00'", 'creationDate': 'D:20250730065856Z', 'page': 2}, page_content='Sparse4DGS: Flow-Geometry Assisted 4D Gaussian Splatting for Dynamic Sparse View Synthesis\nMM ’25, October 27–31, 2025, Dublin, Ireland.\nTime\nGlobal Hash Represetation\nLocal Hexplane Represetation\nSplatting\nDeformation\nField\nMLP\nx, y, z\ns,\nq\nDeformable Points\nFlow Feature\nAggregation\xa0\nPoints\nPoses\nCOLMAP\nN Frames\xa0\nInitialization Points\nFigure 2: Method Overview. Our framework processes Gaussian centers and timestamp 𝑡through: (1) a global-local feature\nencoder, (2) flow-guided feature aggregation, and (3) a compact MLP decoder predicting Gaussian attributes (Δ𝝁, Δ𝒔, Δ𝒒). The\ndeformed Gaussians are rendered with joint optimization of RGB 𝐿1, depth, and 4D pseudo-view constraints. Experimental\nresults demonstrate that our global-local feature representation effectively captures both global and local information, the flow\nprediction module enhances inter-frame feature consistency, and the monocular depth regularization and 4D pseudo-depth\nsupervision effectively address the structural coherence in sparse dynamic scenes.\n3\nPreliminaries\n3.1\n3D Gaussian Splatting\n3DGS optimizes a set of anisotropic 3D Gaussians and employs\ndifferentiable rasterization for rendering. Through its efficient ras-\nterization process, it enables real-time rendering of high-quality\nimages. Each Gaussian𝐺is defined by its 3D center position 𝝁∈R3\nand 3D covariance matrix 𝚺∈R3×3:\n𝐺(𝒙) = 𝑒−1\n2 (𝒙−𝝁)𝑇Í−1(𝒙−𝝁),\n(1)\nwhere the covariance matrixcan 𝚺∈R3×3 can be decomposed to\nfacilitate subsequent optimization as follows: 𝚺= RSS𝑇R𝑇, where\nR ∈R3×3 is a rotation matrix represented by a quaternion 𝒒, and\nS ∈R3×3 is a scaling matrix represented by a 3D vector 𝒔. Each\nGaussian 𝐺is associated with an opacity value 𝛼to control its con-\ntribution during rendering and spherical harmonic (SH) coefficients\n𝑠ℎto model view-dependent color appearance. Thus, the scene is pa-\nrameterized as a collection of Gaussians 𝜁= {𝐺𝑖: 𝝁𝒊, 𝒒𝒊, 𝒔𝒊, 𝛼𝑖,𝑠ℎ𝑖}.\nTo project 3D Gaussians onto a 2D plane for rendering, the\ncovariance matrix 𝚺′ in camera coordinates is computed using the\nworld-to-camera transformation matrix W and the Jacobian J of\nthe projective transformation :\n𝚺′ = JW𝚺W𝑇J𝑇.\n(2)\nSubsequently, the color 𝐶of each pixel is computed by blend-\ning 𝑁depth-ordered Gaussians that overlop this pixel using the\nfollowing 𝛼-blend equation:\n𝐶=\n𝑁\n∑︁\n𝑖=1\n𝒄𝒊𝛼𝑖\n𝑖−1\nÖ\n𝑗=1\n(1 −𝛼𝑗),\n(3)\nwhere 𝒄𝒊and 𝛼𝑖are the color and opacity of the 𝑖−th Gaussian, re-\nspectively, and 𝑁is the number of overlapping Gaussians near this\npixel. By optimizing the Gaussian parameters {𝐺𝑖: 𝝁𝒊, 𝒒𝒊, 𝒔𝒊, 𝛼𝑖,𝑠ℎ𝑖}\nand employing an adaptive density control strategy, high-quality\nimages can be rendered in real time.\nAdditionally, the rasterization process of 3D-GS can be utilized\nto render depth maps. At time 𝑡, the depth value for a pixel is com-\nputed by accumulating the 𝑧−buffer values of the ordered Gaussians\ncontributing to the pixel, as follows:\nˆ𝐷=\n𝑁\n∑︁\n𝑖=1\n𝒅𝒊𝛼𝑖\n𝑖−1\nÖ\n𝑗=1\n(1 −𝛼𝑗),\n(4)\nwhere 𝒅𝒊represents the 𝑧−buffer value of t ...
#  Document(metadata={'producer': 'pdfTeX, Version 3.141592653-2.6-1.40.26 (TeX Live 2024) kpathsea version 6.4.0', 'creator': 'LaTeX with acmart 2025/05/30 v2.14 Typesetting articles for the Association for Computing Machinery and hyperref 2024-01-20 v7.01h Hypertext links for LaTeX', 'creationdate': '2025-07-30T06:58:56+00:00', 'source': '../data/pdfs/Floe Sparse 4DGS.pdf', 'file_path': '../data/pdfs/Floe Sparse 4DGS.pdf', 'total_pages': 10, 'format': 'PDF 1.5', 'title': 'Sparse4DGS: Flow-Geometry Assisted 4D Gaussian Splatting for Dynamic Sparse View Synthesis', 'author': 'Dongdong Hu', 'subject': '-  Computing methodologies  ->  Rendering.Reconstruction.Virtual reality.', 'keywords': '3D Gaussian Splatting; Sparse-View Synthesis; Dynamic Scene Reconstruction', 'moddate': '2025-09-29T14:47:17-04:00', 'trapped': '', 'modDate': "D:20250929144717-04'00'", 'creationDate': 'D:20250730065856Z', 'page': 3}, page_content='MM ’25, October 27–31, 2025, Dublin, Ireland.\nDongdong Hu et al.\nquery feature planes and decodes their features into deformation\nquantities such as position, rotation, and scaling. This deformation\nformulation can be expressed as:\n𝚫𝝁, 𝚫𝒒, 𝚫𝒔= 𝜙𝜇(𝒇𝑫),𝜙𝑞(𝒇𝑫),𝜙𝑠(𝒇𝑫),\n(6)\nwhere 𝜙𝜇(𝒇𝑫),𝜙𝑞(𝒇𝑫),𝜙𝑠(𝒇𝑫) represent the MLP decoders for po-\nsition, rotation, and scaling attributes, respectively, and 𝒇𝑫denotes\nthe encoded feature vector.\nSubsequently, the final Gaussian attributes after deformation\ndecoding can be expressed as:\n(𝝁′, 𝒒′, 𝒔′) = (𝝁+ 𝚫𝝁, 𝒒+ 𝚫𝒒, 𝒔+ 𝚫𝒔).\n(7)\nFinally, the deformed 3D Gaussians 𝐺′ are rendered. In this work,\nwe retain this deformation field-based 4D dynamic Gaussian strat-\negy but enhance it by integrating HexPlane and hash encodings\nfor global-local feature representation. This approach allows us to\nbetter capture high-frequency details in complex local regions.\n4\nMethod\nFigure 2 provides an overview of our sparse 4D GS framework,\nwhich consists of four key components that work sequentially.\nFirst, we introduce a global-local feature extraction module that\ncombines HexPlane encoding for coarse global features and hash\nencoding for fine local details (Section 4.1). Next, we present a flow-\nguided feature aggregation module that utilizes predicted motion\nflow (Section 4.2). Then, we employed a 4D geometric constraint\nstrategy, which includes a Pearson loss term using pre-trained\n2D depth priors and a depth supervision term under pseudo-4D\ncamera poses (Section 4.3). Finally, we outline the loss functions\nused during the optimization process (Section 4.4).\nGlobal HexPlane Represetation\xa0 \xa0 \xa0 \xa0&&\xa0 \xa0 \xa0 \xa0 \xa0 \xa0 Local Hash Represetation\nxy\nxz\nyz\nzt\nyt\nzt\nxyz\nxyt\nxzt\nyzt\nStatic\nDynamic\nDynamic\nStatic\n:\xa0Hadamard Product\n: Concatenate\nFigure 3: Global-local feature representation for dynamic\nscenes. We employ the hexplane and hash volumetric grid\nrepresentations to extract global and local features, respec-\ntively. Each representation can be further decomposed into\nstatic and dynamic components.\n4.1\nGlobal-Local Feature Extraction\nOur proposed global-local scene representation connects Gaussian\npoints in 4D space by integrating both global and local features,\nresulting in a more accurate representation of dynamic scenes.\nFigure 3 illustrates the framework of Global-local feature repre-\nsentation.\nFor the global low-resolution feature representation, inspired\nby HexPlane [4], we introduce a spatial-temporal six-plane feature\nencoder G(𝝁,𝑡), which contains 6 multi-resolution planes P𝑙(𝑖, 𝑗),\nwhere (𝑖, 𝑗) ∈{(𝑥,𝑦), (𝑥,𝑧), (𝑦,𝑧), (𝑥,𝑡), (𝑦,𝑡), (𝑧,𝑡)} and the scale\n𝑙∈{1, 2}, and the position 𝝁= (𝑥,𝑦,𝑧) is the mean value of each 3D\nGaussian. Specifically, we use G to decompose the spatial-temporal\nfeatures of dynamic scenes into 6 orthogonal plane features P𝑙∈\nR𝑀𝑖×𝑀𝑗×𝐶, where 𝑀represents the plane resolution at feature\nscale 𝑙and 𝐶denotes the number of output channels. We then\nseparate the static and dynamic features to ...
#  Document(metadata={'producer': 'pdfTeX, Version 3.141592653-2.6-1.40.26 (TeX Live 2024) kpathsea version 6.4.0', 'creator': 'LaTeX with acmart 2025/05/30 v2.14 Typesetting articles for the Association for Computing Machinery and hyperref 2024-01-20 v7.01h Hypertext links for LaTeX', 'creationdate': '2025-07-30T06:58:56+00:00', 'source': '../data/pdfs/Floe Sparse 4DGS.pdf', 'file_path': '../data/pdfs/Floe Sparse 4DGS.pdf', 'total_pages': 10, 'format': 'PDF 1.5', 'title': 'Sparse4DGS: Flow-Geometry Assisted 4D Gaussian Splatting for Dynamic Sparse View Synthesis', 'author': 'Dongdong Hu', 'subject': '-  Computing methodologies  ->  Rendering.Reconstruction.Virtual reality.', 'keywords': '3D Gaussian Splatting; Sparse-View Synthesis; Dynamic Scene Reconstruction', 'moddate': '2025-09-29T14:47:17-04:00', 'trapped': '', 'modDate': "D:20250929144717-04'00'", 'creationDate': 'D:20250730065856Z', 'page': 4}, page_content="Sparse4DGS: Flow-Geometry Assisted 4D Gaussian Splatting for Dynamic Sparse View Synthesis\nMM ’25, October 27–31, 2025, Dublin, Ireland.\nInput u\xa0\nMLP\nForward Flow\nBackward Flow\n\xa0uf\nFd(t+1)\nFd(t-1)\nFd(t)\nFd\n'\n\xa0ub\nFigure 4: Feature aggregation module based on MLP flow\nprediction. By combining the forward and backward flows to\npredict the Gaussian center positions, the dynamic features\nof the current frame and adjacent frames are aggregated.\ncenter position, respectively. Since static features are independent\nof the temporal domain, we only aggregate dynamic features.\nAs shown in Figure 4, to fully utilize motion information from\nadjacent frames, we compute the dynamic features at positions\nadjusted by flow offsets. It is formulated as:\n𝝁f = 𝝁+ Δ𝝁f, 𝝁b = 𝝁+ Δ𝝁b,\n(13)\n𝑭′\n𝑑= 1\n4 𝑭𝑑(𝝁b,𝑡−1) + 1\n2 𝑭𝑑(𝝁,𝑡) + 1\n4 𝑭𝑑(𝝁f,𝑡+ 1),\n(14)\nwhere 𝝁b and 𝝁f represent the Gaussian center positions in the pre-\nvious and next frames, respectively, 𝑭𝑑(𝝁,𝑡) denotes the dynamic\nglobal-local features of the Gaussian points in the scene at time 𝑡\nand position 𝝁, and 𝑭𝑑is the dynamic features after flow-guided\nfeature aggregation.\nFinally, we feed 𝑭′\n𝑑, along with the global/local static features\n𝑭𝐺\n𝑠and 𝑭𝐿𝑠, into the Gaussian attribute decoder to generate the\ndeformation field. Compared to the single-frame feature encoding\nmethod in 4DGS, our flow-guided dynamic feature aggregation\nensures feature continuity between frames.\n4.3\n4D Geometry Constraint Scheme\n4.3.1\nAligned Depth Regularization.\nIn sparse-view synthesis, 2D depth information is often used to en-\nhance scene structure. Here, we employ a pre-trained 2D monocular\ndepth estimator (DPT) [34] to generate real-time monocular depth\nmaps 𝐷(𝑡)𝑒𝑠𝑡at each timestamp 𝑡during training. Then, instead\nof applying 𝐿1 regularization, we introduce a Pearson correlation\nloss on the normalized depth maps. This loss function measures the\ndistribution differences between the estimated depth map 𝐷(𝑡)𝑒𝑠𝑡\nand rendered depth map ˆ𝐷(𝑡) as:\nLdepth = Pearson(𝐷(𝑡)𝑒𝑠𝑡, ˆ𝐷(𝑡))\n=\nCov(𝐷(𝑡)𝑒𝑠𝑡, ˆ𝐷(𝑡))\n√︃\nVar(𝐷(𝑡)𝑒𝑠𝑡) × Var( ˆ𝐷(𝑡))\n.\n(15)\nThe Pearson loss is relatively robust to outliers. In sparse dy-\nnamic scenarios, it can better align depth structures with large\ndeviations.\nnoisy\nt\xa0\ncam0\ncam1\ncam \n\xa0 pesudo\npesudo image\npesudo depth\nFigure 5: 4D pseudo-viewpoint depth supervision. For any\ntwo training camera viewpoints, we average their poses at the\ncurrent timestamp 𝑡and add random white noise to simulate\nrandom viewpoints.\n4.3.2\n4D Pseudo-Depth Supervision.\nTo address the inherent issue of geometric uncertainty due to sparse\ntraining views during dynamic Gaussian training, we incorporate\nadditional 2D priors into the scene by using unobserved (pseudo)\nview augmentation. Specifically, as shown in Figure 5, for any given\ntimestamp 𝑡, we sample synthetic viewpoints from the two closest\ntraining viewpoints in Euclidean space, computing the average\nviewing direction of the cameras, and interpolate a random virtual\ndire ...
#  Document(metadata={'producer': 'pdfTeX, Version 3.141592653-2.6-1.40.26 (TeX Live 2024) kpathsea version 6.4.0', 'creator': 'LaTeX with acmart 2025/05/30 v2.14 Typesetting articles for the Association for Computing Machinery and hyperref 2024-01-20 v7.01h Hypertext links for LaTeX', 'creationdate': '2025-07-30T06:58:56+00:00', 'source': '../data/pdfs/Floe Sparse 4DGS.pdf', 'file_path': '../data/pdfs/Floe Sparse 4DGS.pdf', 'total_pages': 10, 'format': 'PDF 1.5', 'title': 'Sparse4DGS: Flow-Geometry Assisted 4D Gaussian Splatting for Dynamic Sparse View Synthesis', 'author': 'Dongdong Hu', 'subject': '-  Computing methodologies  ->  Rendering.Reconstruction.Virtual reality.', 'keywords': '3D Gaussian Splatting; Sparse-View Synthesis; Dynamic Scene Reconstruction', 'moddate': '2025-09-29T14:47:17-04:00', 'trapped': '', 'modDate': "D:20250929144717-04'00'", 'creationDate': 'D:20250730065856Z', 'page': 5}, page_content='MM ’25, October 27–31, 2025, Dublin, Ireland.\nDongdong Hu et al.\nTable 1: Quantitative comparison on the Neural 3D Video dataset. We report the PSNR, SSIM, and LPIPS values for all methods\nunder both 4-view and 6-view sparse camera settings. Compared to other dynamic NeRF methods and dynamic Gaussian\nmethods, our method achieves the best performance in rendering quality and image perception. In the table, different colors\nare used to indicate the best and second-best performance.\nMethods\n4views\n6views\nPSNR\nSSIM\nLPIPS\nTime\nPSNR\nSSIM\nLPIPS\nTime\nHexplane[4]\n15.79\n0.586\n0.534\n7hours\n21.73\n0.784\n0.368\n8hours\nMixvoxels[39]\n17.18\n0.721\n0.495\n3hours\n23.43\n0.840\n0.362\n3hours\nHyperreel[1]\n19.76\n0.712\n0.338\n4hours\n21.94\n0.764\n0.340\n4.5hours\n4D GS[41]\n20.94\n0.737\n0.322\n10mins\n23.82\n0.802\n0.273\n15mins\nSpacetime4DGS[18]\n20.57\n0.761\n0.311\n15mins\n24.40\n0.841\n0.239\n20mins\nReal4DGS[45]\n21.04\n0.750\n0.333\n40mins\n24.73\n0.834\n0.244\n1hours\nours\n22.22\n0.797\n0.288\n15mins\n25.85\n0.859\n0.228\n20mins\nsear_steak\nflame_steak\nflame_salmon_1\ncoffee_martini\n4D GS\xa0\nOurs\nGT\nPhoto 4DGS\nSpacetime 4DGS\nHyperreel\nFigure 6: Qualitative results on the Neural 3D Video dataset under 6 sparse camera viewpoints. We present novel view frame\nresults generated by Hyperreel [1], 4DGS [41], Photorealistic 4DGS [45], Spacetime 4DGS [18], and our method.\n5\nExperiments\n5.1\nExperimental Setup\nDataset. We conduct experiments on Neural 3D Video dataset and\nGoogle Immersive dataset.\nThe Neural 3D Video [16] dataset consists of six multi-view\nvideo sequences from the indoor scene, captured by 18 to 21 cameras\nwith a resolution of 2704 × 2028. Following convention, all methods\nare trained and evaluated at half the original video resolution, with\nthe first camera’s video reserved for evaluation. To align with sparse\ncamera inputs, we have selected the first 50 frames from the videos\nof the 1st, 4th, 7th, and 10th cameras to create our initial 4-view\ndataset. Additionally, we have included the videos from the 11th\nand 20th cameras for our 6-view dataset.\nThe Google Immersive [2] dataset contains indoor and outdoor\nscenes captured by 46 cameras with a resolution of 2560 × 1920. Each\ncamera uses a fisheye mode and is mounted on a semi-transparent\nspherical screen. Unlike typical dynamic scene datasets, there is\nminimal overlap between the views, and each video sequence ex-\nhibits significant motion variations. For our evaluation, we select\nsix scenes: Welder, Flames, Truck, Exhibit, Face Paint 1, and Face\nPaint 2. For each scene, we use the camera viewpoint centered on\nthe human subject as the test set, then select the nearest neighbor-\ning cameras as the training set whenever possible. Here, we choose\nvideos from 6 of these cameras as sparse video inputs to train and\nevaluate all methods.\nBaselines. We compare our method with several NeRF-based\ndynamic view synthesis approaches [26], including HexPlane [4],\nHyperreel [1], and Mixvoxels [39]. Additionally, w ...
#  Document(metadata={'producer': 'pdfTeX, Version 3.141592653-2.6-1.40.26 (TeX Live 2024) kpathsea version 6.4.0', 'creator': 'LaTeX with acmart 2025/05/30 v2.14 Typesetting articles for the Association for Computing Machinery and hyperref 2024-01-20 v7.01h Hypertext links for LaTeX', 'creationdate': '2025-07-30T06:58:56+00:00', 'source': '../data/pdfs/Floe Sparse 4DGS.pdf', 'file_path': '../data/pdfs/Floe Sparse 4DGS.pdf', 'total_pages': 10, 'format': 'PDF 1.5', 'title': 'Sparse4DGS: Flow-Geometry Assisted 4D Gaussian Splatting for Dynamic Sparse View Synthesis', 'author': 'Dongdong Hu', 'subject': '-  Computing methodologies  ->  Rendering.Reconstruction.Virtual reality.', 'keywords': '3D Gaussian Splatting; Sparse-View Synthesis; Dynamic Scene Reconstruction', 'moddate': '2025-09-29T14:47:17-04:00', 'trapped': '', 'modDate': "D:20250929144717-04'00'", 'creationDate': 'D:20250730065856Z', 'page': 6}, page_content='Sparse4DGS: Flow-Geometry Assisted 4D Gaussian Splatting for Dynamic Sparse View Synthesis\nMM ’25, October 27–31, 2025, Dublin, Ireland.\nflames\n4D GS\xa0\nReal4DGS\nOurs\nGT\nexhibit\nface_paint_2\nHyperreel\nFigure 7: Qualitative results on the Google Immersive dataset under 6 sparse camera viewpoints. We present novel view frame\nresults generated by Hyperreel [1], 4DGS [41], Photorealistic 4DGS [45], and our method.\nEvaluation Metrics. We report average PSNR, SSIM, and LPIPS\nscores for all methods. Higher PSNR and SSIM values indicate bet-\nter reconstruction quality, while lower LPIPS values correspond to\nsuperior visual perception.\nImplementation Details. Our experiments are conducted on a\nLinux server using the PyTorch 11.7 framework. The initial Gauss-\nian point cloud is generated from the first frame of all training\nvideos using Structure-from-Motion (SFM). The global feature plane\nresolution ranges from 64 to 128 across two scales, while the local\nhash grid resolution ranges from 512 to 32768 across four scales.\nThe flow prediction module uses a 3-layer MLP with 64 hidden units,\nand the deformation field employs a 1-layer MLP with 128 hidden\nunits to ensure model efficiency. We follow the smooth annealing\nmechanism from 4D Gaussian Splatting for Gaussian initialization,\niterating 3,000 times before incorporating the deformation field for\njoint 4D optimization. Pseudo-view sampling is enabled after 1500\niterations to ensure that the Gaussians can roughly represent the\nscene at this stage. During optimization, we avoid resetting the\nopacity of all Gaussians, as this may lead to irreversible optimiza-\ntion issues. Other optimizer parameters remain consistent with\n4DGS. Depth regularization is applied during both the coarse itera-\ntion and joint optimization stages, while pseudo-depth supervision\nis only used during joint optimization. To prevent overfitting, we\nlimit the joint dynamic training to 10,000 iterations and use only\nthe first 50 frames of each camera video for training and testing.\nTraining takes approximately 15 minutes per scene on the Neural\n3D Video dataset and 25 minutes on the Google dataset. All results\nare obtained using a single NVIDIA 3090 GPU with 24GB memory.\n5.2\nComparison on Neural 3D Video Dataset\nAs shown in the quantitative results in Table 1, our method outper-\nforms other dynamic novel view synthesis methods, reporting the\nbest quantitative results for both 4-view and 6-view sparse camera\ninputs. This outcome shows that our global-local representation\nTable 2: Quantitative comparison on the Google Immersive\ndataset. We report the PSNR, SSIM, and LPIPS values of all\nmethods under the setting of 6 sparse viewpoints. In the table,\ndifferent colors are used to indicate the best and second-best\nperformance.\nMethods\nPSNR\nSSIM\nLPIPS\nTime\nHexplane[4]\n15.84\n0.547\n0.573\n8hours\nMixvoxels[39]\n16.69\n0.587\n0.528\n4hours\n4D GS[41]\n17.30\n0.603\n0.485\n20mins\nReal4DGS[45]\n17.96\n0.626\n0.463\n1hours\nHyperreel[1]\n18.50\n0.624\n0.473\n2.5 ...
#  Document(metadata={'producer': 'pdfTeX, Version 3.141592653-2.6-1.40.26 (TeX Live 2024) kpathsea version 6.4.0', 'creator': 'LaTeX with acmart 2025/05/30 v2.14 Typesetting articles for the Association for Computing Machinery and hyperref 2024-01-20 v7.01h Hypertext links for LaTeX', 'creationdate': '2025-07-30T06:58:56+00:00', 'source': '../data/pdfs/Floe Sparse 4DGS.pdf', 'file_path': '../data/pdfs/Floe Sparse 4DGS.pdf', 'total_pages': 10, 'format': 'PDF 1.5', 'title': 'Sparse4DGS: Flow-Geometry Assisted 4D Gaussian Splatting for Dynamic Sparse View Synthesis', 'author': 'Dongdong Hu', 'subject': '-  Computing methodologies  ->  Rendering.Reconstruction.Virtual reality.', 'keywords': '3D Gaussian Splatting; Sparse-View Synthesis; Dynamic Scene Reconstruction', 'moddate': '2025-09-29T14:47:17-04:00', 'trapped': '', 'modDate': "D:20250929144717-04'00'", 'creationDate': 'D:20250730065856Z', 'page': 7}, page_content='MM ’25, October 27–31, 2025, Dublin, Ireland.\nDongdong Hu et al.\nsmoothing in dynamic scenes,as evidenced by the disappearing\nblack dots in the background shown in Figure 6. In contrast, our\nmethod successfully recovers significantly more texture and struc-\ntural details, whether in low-frequency background regions (like\nthe red wine on the table) or localized high-frequency areas (such\nas the moving hand in the scene), demonstrating the validity of our\napproach for sparse dynamic scene modeling.\n5.3\nComparison on Google Immersive Dataset\nUnlike the Neural 3D Video dataset [16], the Google Immersive\ndataset [2] presents significant challenges due to substantial off-\nsets between camera viewpoints and rapid motion in the videos.\nAs shown in the quantitative results in Table 2, dynamic NeRF\nmethods (e.g., HexPlane[4], MixVoxels[39]) that require dense view\ncoverage perform considerably worse than our approach in terms of\nboth rendering speed and view synthesis quality. Another dynamic\nNeRF method, Hyperreel[1], achieves quality metrics close to ours\nbut produces poor visual results, rendering extremely blurry dy-\nnamic scenes, as shown in Figure 7. Real-time rendering methods\nwith dynamic GS encounter limitations in rendering quality for\nsparse-view dynamic scenes. In contrast, our method significantly\noutperforms these approaches, improving PSNR by approximately\n1 dB while maintaining fast training times, comparable to the quick-\nest method (e.g., 4DGS[41]).\nWe present qualitative comparisons in Figure 7. We observe\nthat dynamic NeRF methods struggle to reconstruct sparse-view\ndynamic scenes. In addition, dynamic GS methods fail to capture\nthe intricate details of the scene, resulting in the loss of structural\ninformation for specific objects, such as the woman’s hair in Fig-\nure 7. In contrast, our method successfully recovers most scene\ndetails, including moving characters and static background regions.\nTable 3: Ablation study of each module. From the results in\nthe table, both the flow-guided global-local feature extrac-\ntion and 4D pseudo-depth constraints yield certain effects\ncompared to the cases without them.\nFlow\nLocal\nDepth\nPSNR\nSSIM\nLPIPS\n×\n×\n×\n23.82\n0.802\n0.273\n✓\n✓\n×\n25.01\n0.842\n0.242\n×\n×\n✓\n25.32\n0.859\n0.215\n✓\n✓\n✓\n25.85\n0.859\n0.228\n5.4\nAblation Study\nWe conduct ablation studies on all proposed modules using the\n6-camera-view setting of the Neural 3D Video dataset. Quantitative\nresults are reported in Table 3 and qualitative figures are shown in\nFigure 8.\nEffectiveness of the Flow-Guided Global-Local Feature Ag-\ngregation Module. Our proposed global-local representation and\nflow-guided feature aggregation module work together to improve\nscene representation, so we combine them for ablation experiments.\nAs shown in the second row of Table 3 and the first row of Fig-\nure 8, excluding these two modules shows limitations in modeling\ncomplex object deformations across various scenarios. By incorpo-\nrating the flow-guided global-loca ...
#  Document(metadata={'producer': 'pdfTeX, Version 3.141592653-2.6-1.40.26 (TeX Live 2024) kpathsea version 6.4.0', 'creator': 'LaTeX with acmart 2025/05/30 v2.14 Typesetting articles for the Association for Computing Machinery and hyperref 2024-01-20 v7.01h Hypertext links for LaTeX', 'creationdate': '2025-07-30T06:58:56+00:00', 'source': '../data/pdfs/Floe Sparse 4DGS.pdf', 'file_path': '../data/pdfs/Floe Sparse 4DGS.pdf', 'total_pages': 10, 'format': 'PDF 1.5', 'title': 'Sparse4DGS: Flow-Geometry Assisted 4D Gaussian Splatting for Dynamic Sparse View Synthesis', 'author': 'Dongdong Hu', 'subject': '-  Computing methodologies  ->  Rendering.Reconstruction.Virtual reality.', 'keywords': '3D Gaussian Splatting; Sparse-View Synthesis; Dynamic Scene Reconstruction', 'moddate': '2025-09-29T14:47:17-04:00', 'trapped': '', 'modDate': "D:20250929144717-04'00'", 'creationDate': 'D:20250730065856Z', 'page': 8}, page_content='Sparse4DGS: Flow-Geometry Assisted 4D Gaussian Splatting for Dynamic Sparse View Synthesis\nMM ’25, October 27–31, 2025, Dublin, Ireland.\nReferences\n[1] Benjamin Attal, Jiabin Huang, Christian Richardt, Michael Zollhoefer, Johannes\nKopf, Matthew O’Toole, and Changil Kim. 2023. HyperReel: High-fidelity 6-DoF\nvideo with ray-conditioned sampling. In Proceedings of the IEEE/CVF Conference\non Computer Vision and Pattern Recognition. 16610–16620.\n[2] Michael Broxton, John Flynn, Ryan Overbeck, Daniel Erickson, Peter Hedman,\nMatthew Duvall, Jason Dourgarian, Jay Busch, Matt Whalen, and Paul Debevec.\n2020. Immersive light field video with a layered mesh representation. ACM\nTransactions on Graphics (TOG) 39, 4 (2020), 86–1.\n[3] Yuanhao Cai, Zihao Xiao, Yixun Liang, Minghan Qin, Yulun Zhang, Xiaokang\nYang, Yaoyao Liu, and Alan L Yuille. 2024. Hdr-gs: Efficient high dynamic range\nnovel view synthesis at 1000x speed via gaussian splatting. Advances in Neural\nInformation Processing Systems 37 (2024), 68453–68471.\n[4] Ang Cao and Justin Johnson. 2023. Hexplane: A fast representation for dynamic\nscenes. In Proceedings of the IEEE/CVF Conference on Computer Vision and Pattern\nRecognition. 130–141.\n[5] David Charatan, Sizhe Lester Li, Andrea Tagliasacchi, and Vincent Sitzmann.\n2024. pixelsplat: 3d gaussian splats from image pairs for scalable generalizable\n3d reconstruction. In Proceedings of the IEEE/CVF conference on computer vision\nand pattern recognition. 19457–19467.\n[6] Jiahao Chen, Yipeng Qin, Lingjie Liu, Jiangbo Lu, and Guanbin Li. 2024. Nerf-\nhugs: Improved neural radiance fields in non-static scenes using heuristics-guided\nsegmentation. In Proceedings of the IEEE/CVF Conference on Computer Vision and\nPattern Recognition. 19436–19446.\n[7] Yuedong Chen, Haofei Xu, Chuanxia Zheng, Bohan Zhuang, Marc Pollefeys,\nAndreas Geiger, Tat-Jen Cham, and Jianfei Cai. 2024. Mvsplat: Efficient 3d\ngaussian splatting from sparse multi-view images. In European Conference on\nComputer Vision. Springer, 370–386.\n[8] Zheng Chen, Chen Wang, Yuanchen Guo, and Songhai Zhang. 2023. Structnerf:\nNeural radiance fields for indoor scenes with structural hints. IEEE Transactions\non Pattern Analysis and Machine Intelligence 45, 12 (2023), 15694–15705.\n[9] Yuheng Jiang, Zhehao Shen, Penghao Wang, Zhuo Su, Yu Hong, Yingliang Zhang,\nJingyi Yu, and Lan Xu. 2024. Hifi4g: High-fidelity human performance rendering\nvia compact gaussian splatting. In Proceedings of the IEEE/CVF conference on\ncomputer vision and pattern recognition. 19734–19745.\n[10] Kai Katsumata, Duc Minh Vo, and Hideki Nakayama. 2024. A compact dynamic\n3d gaussian representation for real-time dynamic view synthesis. In European\nConference on Computer Vision. Springer, 394–412.\n[11] Bernhard Kerbl, Georgios Kopanas, Thomas Leimkühler, and George Drettakis.\n2023. 3d gaussian splatting for real-time radiance field rendering. ACM Trans.\nGraph. 42, 4 (2023), 139–1.\n[12] Seoha Kim, Jeongmin Bae, Youngsik Yun, Hahyun Lee, Gun Bang, and Youngjung\nUh. 2024. Syn ...
#  Document(metadata={'producer': 'pdfTeX, Version 3.141592653-2.6-1.40.26 (TeX Live 2024) kpathsea version 6.4.0', 'creator': 'LaTeX with acmart 2025/05/30 v2.14 Typesetting articles for the Association for Computing Machinery and hyperref 2024-01-20 v7.01h Hypertext links for LaTeX', 'creationdate': '2025-07-30T06:58:56+00:00', 'source': '../data/pdfs/Floe Sparse 4DGS.pdf', 'file_path': '../data/pdfs/Floe Sparse 4DGS.pdf', 'total_pages': 10, 'format': 'PDF 1.5', 'title': 'Sparse4DGS: Flow-Geometry Assisted 4D Gaussian Splatting for Dynamic Sparse View Synthesis', 'author': 'Dongdong Hu', 'subject': '-  Computing methodologies  ->  Rendering.Reconstruction.Virtual reality.', 'keywords': '3D Gaussian Splatting; Sparse-View Synthesis; Dynamic Scene Reconstruction', 'moddate': '2025-09-29T14:47:17-04:00', 'trapped': '', 'modDate': "D:20250929144717-04'00'", 'creationDate': 'D:20250730065856Z', 'page': 9}, page_content='MM ’25, October 27–31, 2025, Dublin, Ireland.\nDongdong Hu et al.\n[45] Zeyu Yang, Hongye Yang, Zijie Pan, and Li Zhang. 2023. Real-time photorealistic\ndynamic scene representation and rendering with 4d gaussian splatting. arXiv\npreprint arXiv:2310.10642 (2023).\n[46] Zehao Yu, Anpei Chen, Binbin Huang, Torsten Sattler, and Andreas Geiger. 2024.\nMip-splatting: Alias-free 3d gaussian splatting. In Proceedings of the IEEE/CVF\nconference on computer vision and pattern recognition. 19447–19456.\n[47] Jiahui Zhang, Fangneng Zhan, Muyu Xu, Shijian Lu, and Eric Xing. 2024. Fregs: 3d\ngaussian splatting with progressive frequency regularization. In Proceedings of the\nIEEE/CVF Conference on Computer Vision and Pattern Recognition. 21424–21433.\n[48] Boming Zhao, Yuan Li, Ziyu Sun, Lin Zeng, Yujun Shen, Rui Ma, Yinda Zhang,\nHujun Bao, and Zhaopeng Cui. 2024. Gaussianprediction: Dynamic 3d gaussian\nprediction for motion extrapolation and free view synthesis. In ACM SIGGRAPH\n2024 Conference Papers. 1–12.\n[49] Yuyang Zhao, Zhiwen Yan, Enze Xie, Lanqing Hong, Zhenguo Li, and Gim Hee\nLee. 2023. Animate124: Animating one image to 4d dynamic scene. arXiv preprint\narXiv:2311.14603 (2023).\n[50] Zehan Zheng, Danni Wu, Ruisi Lu, Fan Lu, Guang Chen, and Changjun Jiang.\n2023. Neuralpci: Spatio-temporal neural field for 3d point cloud multi-frame\nnon-linear interpolation. In Proceedings of the IEEE/CVF Conference on Computer\nVision and Pattern Recognition. 909–918.\n[51] Shijie Zhou, Haoran Chang, Sicheng Jiang, Zhiwen Fan, Zehao Zhu, Dejia Xu,\nPradyumna Chari, Suya You, Zhangyang Wang, and Achuta Kadambi. 2024.\nFeature 3dgs: Supercharging 3d gaussian splatting to enable distilled feature\nfields. In Proceedings of the IEEE/CVF Conference on Computer Vision and Pattern\nRecognition. 21676–21685.\n10651')]

# %%
type(pdf_documents[0])
# Out:
# langchain_core.documents.base.Document
